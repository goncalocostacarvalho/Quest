# %%
def full_game():
    import time
    def act_break(): #function to be used to separate the different chapters
        print("")
        print("")
    def print_slow(text, delay=1.5): #function to be used to delay the next message to user be able to read the message
        print(text)
        time.sleep(delay)
    def scenario():
        print_slow("In a mystical land, there exists a prophecy about an Enchanted Orb that has the power to bring balance to the realms.")
        print("")
        print_slow("The orb, however, has been lost for centuries.")
        print("")
        print_slow("Legends speak of a hidden cave where the orb is said to be guarded by magical creatures and traps.")
        valid_answer=False
        while not valid_answer:
            try:
                print("")
                response=input("Are you ready to embrace the adventure?\nType yes or no.\n")
                if response.lower() == "yes":
                    print("")
                    print_slow("Let's get started!")
                    valid_answer=True
                elif response.lower()== "no":
                    print_slow("Sorry but you are brave and need to embrace the adventure!")
                else:
                    raise ValueError("Invalid answer! Type yes or no.")
            except ValueError as error:
                print("")
                print_slow(f"Error: {error}")
    def choose_character():
        characters=["Warrior", "Wise", "Enchantress", "Guardian" ]
        name=input("What is your name? ")
        valid_answer=False
        while not valid_answer:
            try:
                character=input(f"Guess your character from {characters}.\n")
                if character.lower()=="warrior":
                    print("")
                    print_slow(f"Congrats! Now, you are {name}, the {character}. Let the adventure begin!")
                    valid_answer=True
                else:
                    raise ValueError("Invalid Answer! To start this game you need to choose another character.")
            except ValueError as error:
                print("")
                print_slow(f"Error: {error}")    
    def act_1():
        print_slow(f"You are at home and suddenly you hear knockning your door.")
        print("")
        valid_answer=False
        while not valid_answer:
            try:
                action_1=input("What you do? Type nothing or check.\n")
                if action_1.lower()=="check":
                    print("")
                    print_slow(f"You found no one at the door. But on the ground there is a letter.")
                    print("")
                    print_slow(f"This letter instructs you to meet Eldor the Wise in Eldoria.")
                    print("")
                    print_slow("Now you have another decision to make!")
                    print("")
                    valid_answer=True 
                elif action_1.lower()=="nothing":
                    print("")
                    print_slow(f"You are not the type of people who does nothing. Try to check what happened.")
                else:
                    raise ValueError("Invalid answer. Type nothing or check.")
            except ValueError as error:
                print("")
                print_slow(f"Error: {error}")  
        valid_answer_2=False
        while not valid_answer_2:
            try:
                action_2=input("You either visit Eldor the Wise or stay at home.\nType visit or stay.\n")
                if action_2.lower()=="visit":
                    print("")
                    print_slow(f"You arrive Eldoria and meet Eldor the Wise.")
                    print("")
                    print_slow(f"He shares the prophecy with you and informs you of the hidden cave's general location.")
                    print("")
                    print_slow(f"Now you are in charge to find the Enchanted Orb and to bring peace and balance to the realms.")
                    valid_answer_2=True
                elif action_2.lower()=="stay":
                    print("")
                    print_slow(f"If you decide to stay at home, there will be no peace and balance! Please rethink your action.")
                else:
                    raise ValueError("Invalid answer. Type visit or stay.")    
            except ValueError as error:
                print("")
                print_slow(f"Error: {error}")
    def act_2():
        print_slow(f"With the hidden cave's general location in mind, you decide to start your adventure.")
        print("")
        print_slow(f"On your way, you find Sylvan, the Enchantress who for a long time didn't see anyone cross her mystical forest.")
        print("")
        print_slow(f"She starts to talk with you and soon you understand that you will need her help to access the hidden cave.")
        print("")
        print_slow(f"She tells you she can give her help but you need to find a rare flower.")
        print("")
        valid_answer=False
        while not valid_answer:
            try:
                action_3=input("What you decide to do?\nType explore or chat.\n")
                if action_3.lower()=="chat":
                    print("")
                    print_slow(f"You decide to chat a bit more!")
                    print("")
                    print_slow(f"You get to know each other better but she insists that only with the rare flower can guide you.")
                    print("")
                elif action_3.lower()=="explore":
                    print("")
                    print_slow(f"You decide to explore!")
                    print("")
                    print_slow(f"While you explore the mystical forest, you discover an hidden grove and the rare flower Sylvan wants.")
                    print("")
                    print_slow(f"You return and give the flower to Sylvan.")
                    valid_answer=True
                else:
                    raise ValueError("Invalid answer. Type explore or chat.")
            except ValueError as error:
                print("")
                print_slow(f"Error: {error}") 
        print("")
        print_slow(f"Sylvan decides to give her guidance and takes you to the cave.")
    def act_3():
        tasks=["puzzles", "traps", "creatures"]
        print_slow(f"Armed with Sylvan's guidance, you enter the cave.")
        print("")
        print_slow(f"Looking around you see puzzles, traps and creatures guarding the path.")
        print("")
        superpowers=set()
        valid_answer=False
        while not valid_answer:
            task=input(f"Choose a task you want to complete from {tasks}.\nIn case you don't want to complete any task, type pass.\n")
            try: 
                if task.lower()=="puzzles":
                    print("")
                    print_slow(f"Congrats! After hours of patience, the task was complete. You obtained patience as a super power!")
                    print("")
                    finish=input("Do you want to complete more tasks?\nType yes or no.\n")
                    print("")
                    superpowers.add("patience")
                    valid_answer=finish=="no"
                elif task.lower()=="traps":
                    print("")
                    print_slow(f"Congrats! You were able to avoid all the traps. You obtained intelligence as a super power!")
                    print("")
                    finish=input("Do you want to complete more tasks?\nType yes or no.\n")
                    print("")
                    superpowers.add("intelligence")
                    valid_answer=finish=="no"
                elif task.lower()=="creatures":
                    print("")
                    print_slow(f"Congrats! After hours of fight, the task was complete. You obtained strenght as a super power!")
                    print("")
                    finish=input("Do you want to complete more tasks?\nType yes or no.\n")
                    print("")
                    superpowers.add("strength")
                    valid_answer=finish=="no"
                elif task.lower()=="pass":
                    print("")
                    print_slow(f"Congrats! You obtained no super power!")
                    valid_answer=True
                else:
                    raise ValueError("Invalid answer. Type one of the tasks or pass.")
            except ValueError as error:
                print("")
                print_slow(f"Error: {error}")
        print("")
        print_slow(f"Your choices inside the cave influenced your abilities.\nHope you are ready for your biggest challenge in this journey.")
        print("")
        print(f"You accquired the following superpowers: {superpowers}.")
        return superpowers
    def act_4(superpowers):
        approach=["outsmart", "battle", "debate"]
        print_slow(f"After facing some challenges or not, in the heart of the cave you found Grimclaw, the Guardian.")
        valid_answer=False
        while not valid_answer:
            if "intelligence" not in superpowers and "strength" not in superpowers and "patience" not in superpowers:
                print("")
                print_slow(f"You didn't face any challenge and don't have any superpower.\nYou can not pass through Grimclaw.")
                print("")
                print_slow(f"Your journey ends here and there is no need to advance.")
                return False
            else:
                print("")
                print_slow(f"To reach the Enchanted Orb, you can face Grimclaw in different ways: {approach}.")
                print("")
                decision=input("Choose the way you want to face Grimclaw.\n")
            try:
                if decision.lower()=="outsmart": 
                    if "intelligence" in superpowers:
                        print("")
                        print_slow(f"Due the intelligence you gained before, you were able to outsmart and surprass Grimclaw.") 
                        valid_answer=True
                    else:
                        print("")
                        print_slow(f"You don't have the superpower needed to outsmart Grimclaw. Choose another way to face Grimclaw.")
                elif decision.lower()=="battle":
                    if "strength" in superpowers:
                        print("")
                        print_slow(f"Due the strength you gained before, you enter on an intense battle with Grimclaw and you claim the victory.") 
                        valid_answer=True
                    else:
                        print("")
                        print_slow(f"You don't have the superpower needed to battle Grimclaw. Choose another way to face Grimclaw.")
                elif decision.lower()=="debate": 
                    if "patience" in superpowers:
                        print("")
                        print_slow(f"Due the patience you gained before, you explained to Grimclaw that the Enchanted Orb was necessary to bring peace and balance to the realms.\nYou became friends and Grimclaw let you pass.")
                        valid_answer=True
                    else:
                        print("")
                        print_slow(f"You don't have the superpower needed to explain the situation you face to Grimclaw. Choose another way to face Grimclaw.")
                else:
                    raise ValueError("Invalid answer. Type one of the correct ways to face Grimclaw.")
            except ValueError as error:
                print("")
                print_slow(f"Error: {error}")
        print("")
        print_slow(f"After this, you are almost on the end of your journey.")
        return True
    def act_5():
        print_slow(f"You finally reach the chamber containing the Enchanted Orb.")
        print("")
        print_slow(f"Now you have a final decision to make.\nTake the orb with you or not.")
        print("")
        print_slow(f"A lot of thoughts come to your mind, especially the one:\nYou either die a hero or live long enough to become the villain.")
        valid_answer=False
        while not valid_answer:
            try:
                final_decision=input("In the end what do you choose to do?\nType abandon or reclaim.\n")
                if final_decision.lower()=="abandon":
                    print("")
                    print_slow(f"You let your invasive thougts get the most of you and you abandon the chamber.\nYour journey was impressive but you weren't able to bring peace and balance to the realms.")
                    valid_answer=True
                    return
                elif final_decision.lower()=="reclaim":
                    print("")
                    print_slow(f"You reclaimed the enchanted orb and you were able to bring peace and balance to the realms.\nYou became a hero to your land!")
                    valid_answer=True
                else:
                    raise ValueError("Invalid answer. Type abandon or reclaim.")
            except ValueError as error:
                print("")
                print_slow(f"Error: {error}.")

    print_slow("Welcome to the Enchanted Orb Adventure!")
    print("")
    print_slow("Your journey begins now.")
    print("")
    scenario()
    act_break()
    choose_character()
    act_break()
    act_1()
    act_break()
    act_2()
    act_break()
    superpowers = act_3()
    act_break()
    if act_4(superpowers):
        act_break()
        act_5()
        print("")
        print_slow(f"The end! Hope you liked!")

# %%
full_game()
